# %% [markdown]
# # データの標準化

# %%
# 数値計算やデータフレーム操作に関するライブラリをインポートする
import numpy as np
import pandas as pd
# 図やグラフを図示するためのライブラリをインポートする。
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn #機械学習のライブラリ
from sklearn.decomposition import PCA #主成分分析器
df = pd.read_csv("seiseki.csv")#デーた(seiseki.csv）の読み込み
df.head()#上から5人の成績の開示
# Out:
#    kokugo  shakai  sugaku  rika  ongaku  bijutu  taiiku  gika  eigo
# 0      30      43      51    63      60      66      37    44    20
# 1      39      21      49    56      70      72      56    63    16
# 2      29      30      23    57      69      76      33    54     6
# 3      95      87      77   100      77      82      78    96    87
# 4      70      71      78    67      72      82      46    63    44

# %%
#各列に対して、平均値を引いたものを標準偏で割る
dfs = df.apply(lambda x: (x-x.mean())/x.std(), axis=0)
dfs.head()
# Out:
#      kokugo    shakai    sugaku      rika    ongaku    bijutu    taiiku  \
# 0 -1.022691  0.158349  0.222211  0.612592  0.771731  0.206080 -0.780383
# 1 -0.610524 -0.866989  0.139690  0.285614  1.208511  0.555155 -0.065504
# 2 -1.068487 -0.447533 -0.933089  0.332325  1.164833  0.787871 -0.930883
# 3  1.954064  2.209025  1.294990  2.340908  1.514256  1.136946  0.762250
# 4  0.809159  1.463325  1.336251  0.799437  1.295866  1.136946 -0.441756
#
#        gika      eigo
# 0 -0.146861 -0.646766
# 1  0.696856 -0.782325
# 2  0.297200 -1.121224
# 3  2.162259  1.623855
# 4  0.696856  0.166591

# %% [markdown]
# # scikit-learnの主成分分析

# %%
#主成分分析の実行()
pca = PCA()
pca.fit(dfs)
# データを主成分空間に写像
feature = pca.transform(dfs)

# %%
# 主成分得点(主成分スコア)
pd.DataFrame(feature, columns=["PC{}".format(x + 1) for x in range(len(dfs.columns))]).head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  0.056415  0.916870 -0.115763  1.188901  0.828176  0.096619 -0.366566
# 1 -0.147906 -0.000470  0.659867  1.178344  1.236977  0.692963  0.438794
# 2  0.540050  0.542761  0.963296  1.847074  1.092440 -0.048715 -0.341034
# 3 -5.107249  0.228059  0.625819 -0.580088  0.292574 -0.368834 -0.301719
# 4 -2.636544  0.661026  0.012114  0.879777  0.046665 -0.464677  0.195361
#
#         PC8       PC9
# 0  0.271820 -0.091322
# 1 -0.209384 -0.060319
# 2 -0.500300  0.156104
# 3  0.242537  0.313485
# 4  0.287273 -0.632364

# %%
# 寄与率
pd.DataFrame(pca.explained_variance_ratio_, index=["PC{}".format(x + 1) for x in range(len(dfs.columns))])
# Out:
#             0
# PC1  0.667381
# PC2  0.122021
# PC3  0.054538
# PC4  0.045220
# PC5  0.033362
# PC6  0.024607
# PC7  0.020310
# PC8  0.019022
# PC9  0.013540

# %%
#負荷量
pca.components_
# Out:
# array([[-0.36263912, -0.36856961, -0.35689514, -0.36722558, -0.35430912,
#         -0.31267797, -0.1392482 , -0.31672623, -0.35694891],
#        [-0.149422  ,  0.14702929,  0.18143655,  0.25068552, -0.009508  ,
#         -0.31216761, -0.85929804,  0.1489576 ,  0.04661005],
#        [ 0.07362261, -0.06155139, -0.39968047,  0.00825064, -0.19960613,
#          0.26378253, -0.08026368,  0.78386882, -0.31727301],
#        [-0.23644316, -0.10652413,  0.02947574,  0.06664423,  0.35687974,
#          0.7122689 , -0.28424799, -0.29335748, -0.35481163],
#        [-0.30146753, -0.08665121, -0.06112359,  0.26238053,  0.64239178,
#         -0.44012475,  0.26856579,  0.18981367, -0.33837177],
#        [-0.49406321, -0.57274499,  0.40814954,  0.03885774, -0.13194764,
#          0.13630896,  0.10663445,  0.28664886,  0.36088773],
#        [ 0.61999142, -0.51698723,  0.4088978 , -0.17650609,  0.1194373 ,
#         -0.12478363, -0.12755626,  0.04150031, -0.3196153 ],
# ...

# %%
# 第一主成分と第二主成分でプロットする
plt.figure()
plt.scatter(feature[:, 0], feature[:, 1], alpha=1)
plt.grid()
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
